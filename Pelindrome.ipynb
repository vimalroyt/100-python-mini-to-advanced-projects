# %% [markdown]
# `Q1. You are given a list of strings. Write a function to filter out all strings that are palindromes.`
#
# ##### **A palindrome is a word, phrase, number, or other sequences of characters that reads the same forward and backward (ignoring spaces, punctuation, and capitalization).**

# %%
def is_palindrome(text):
    if text[::]==text[::-1]:
        print(text)
    else:
        None

is_palindrome("161") #It should be returned
is_palindrome("123")
is_palindrome("radar") #It should be returned

is_palindrome("Spoon")
# Out:
# 161
# radar

# %%
#The same work but in a bit advanced way.

def is_palindrome(s):
    s = ''.join(e for e in s if e.isalnum())  # Remove punctuation and spaces
    return s.lower() == s.lower()[::-1]

def filter_palindromes(strings):
    return [s for s in strings if is_palindrome(s)]

words = ["radar", "python", "level", "world"]
print(filter_palindromes(words))  #Expected output: ['radar', 'level']
# Out:
# ['radar', 'level']
