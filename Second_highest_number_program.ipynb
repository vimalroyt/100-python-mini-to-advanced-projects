# %%
# This function will print the second highest number from the list

def second_highest_num(n):
    n=list(set(n))
    n.sort()
    return n[-2]

n=[1,3,5,4,6,8,6,9,8]
second_highest_num(n)
# Out:
# 8
